# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
data = [
    [-8266.0, -8191.0, -8371.0, -8197.0, -8231.0],
    [-9221.0, -9224.0, -9307.0, -9260.0, -9302.0],
    [-9085.0, -9282.0, -9014.0, -8912.0, -9160.0]
]




labels = ['classic ma', 'qhea', 'only local']

# %%
n_bins = 10

for i in range(len(data)):
    print(f'---------- Data Set {i+1} ----------')
    print(f'{labels[i]}')
    print(f'Mean: {statistics.mean(data[i])}')
    print(f'Median: {statistics.median(data[i])}')
    print(f'Variance: {statistics.variance(data[i])}')
    print(f'Standard Derv: {statistics.stdev(data[i])}')





plt.hist(data, n_bins, histtype='bar', density=False)
plt.legend(labels)
plt.ylabel('Frequency')
plt.xlabel('Fitness')
plt.show()
# Out:
# ---------- Data Set 1 ----------
# classic ma
# Mean: -8251.2
# Median: -8231.0
# Variance: 5385.2
# Standard Derv: 73.3839219447966
# ---------- Data Set 2 ----------
# qhea
# Mean: -9262.8
# Median: -9260.0
# Variance: 1687.7
# Standard Derv: 41.08162606324146
# ---------- Data Set 3 ----------
# only local
# Mean: -9090.6
# Median: -9085.0
# Variance: 19811.8
# Standard Derv: 140.75439602371216
